# %%
# %matplotlib notebook

# %%
import numpy as np
from sklearn.pipeline import Pipeline
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import StratifiedKFold, cross_val_score
from sklearn.model_selection import GridSearchCV

# %%
import pandas as pd

# %%
from sklearn.datasets import load_breast_cancer

# %%
cancer = load_breast_cancer()

cancer.data.shape

cancer.keys()

tabla_cancer = pd.DataFrame(data=cancer.data, columns=cancer.feature_names)

tabla_cancer.head()

# %%
cancer_scaled = StandardScaler().fit_transform(tabla_cancer)

# %%
tabla_cancer_scaled = pd.DataFrame(data=cancer_scaled, columns=cancer.feature_names)

# %%
tabla_cancer_scaled.boxplot()
# Out:
# <img src="data:image/png;base64,..." width="639.85">

# %%
mlpc = MLPClassifier()

# %%
alpha = np.arange(0.01, 2, 0.01)

# %%
activation = ["logistic", "identity", "relu"]

# %%
hidden_layer = [(100,), (100,1), (100,2)]

# %%
param_grid = {'alpha': alpha,
               'activation': activation,
               'hidden_layer_sizes': hidden_layer
               #'classify__n_neighbors': K_NEIGH
              }

# %%
grid = GridSearchCV(mlpc, cv=5, n_jobs=2, param_grid=param_grid)

# %%
grid.fit(X=tabla_cancer_scaled, y=cancer.target)
# Out:
# /home/ramon/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/ramon/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# /home/ramon/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ...

# %% [markdown]
# ### LLaves de los resultados almacenados después del fit

# %%
sorted(grid.cv_results_.keys())

# %% [markdown]
# ### Score en test para los diferentes arreglos de parametros

# %%
mean_scores = np.array(grid.cv_results_['mean_test_score'])

# %% [markdown]
# ### Mejor clasificador

# %%
grid.best_estimator_
