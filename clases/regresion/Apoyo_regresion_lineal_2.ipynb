# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import numpy as np
import matplotlib.pyplot as plt
import sklearn as sk

# %% [markdown]
# # Ecuación de un sistema lineal de una sola variable

# %% [markdown]
# ## $Y = \beta_0 + \beta_1 x + \epsilon$

# %%
ruido = np.random.normal(size=100)

# %%
x = np.linspace(0, 20, 100)
y = (5*x) + 1 + (ruido*10)

# %%
plt.plot(x, y)

# %%
def lineal_model(sigma, N=100):
    ruido = np.random.normal(size=N)
    x = np.linspace(0, 20, N)
    y = (5 * x) + 1 + (ruido * sigma)
    plt.plot(x, y, 'ro')
    return x, y
x, y = lineal_model(10)

# %%
x, y = lineal_model(2)

# %%
#x2, y2 = lineal_model(20, 100)
plt.boxplot([(y2+100),y])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f79b4937860>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f79b4940be0>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f79b494fb00>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f79b4947c50>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f79b4937a20>,
# ...
#   <matplotlib.lines.Line2D at 0x7f79b4958cf8>]}

# %%
plt.boxplot([x,y])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0xab99d06c>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0xab9a292c>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0xab9a7a4c>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xab9a792c>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0xab99da6c>,
# ...
#   <matplotlib.lines.Line2D at 0xab9a778c>]}

# %% [markdown]
# # Son tres métodos principales:
# - fit()
# - predict()
# - score()

# %%
from sklearn import linear_model
model = linear_model.LinearRegression()
x = x.reshape(-1,1)
model.fit(X=x, y=y)
print(model.intercept_,  model.coef_)
# Out:
# -0.625486548192 [ 5.1710713]

# %%
x_new = np.linspace(20,40,5).reshape(-1,1)
y_pred = model.predict(X=x_new)
plot(x,y)
plot(x_new,y_pred)

# %%
def aproxima(x, y):
    x = x.reshape(-1,1)
    model.fit(X=x, y=y)
    return model.intercept_, model.coef_
def lineal_model(sigma, N=100):
    ruido = np.random.normal(size=N)
    x = np.linspace(0, 20, N)
    y = (5*x) + 1 + (ruido*sigma)
    # plt.plot(x, y, 'ro')
    return x, y
fig, axes = plt.subplots(1,2)
axes = axes.reshape(-1,)
y0l = []
ml = []
for sigma in range(10, 1000):
    x, y = lineal_model(sigma)
    y0, m = aproxima(x, y)
    y0l.append(y0)
    ml.append(m)
axes[0].plot(y0l)
axes[1].plot(ml)
fig.show()
plt.show()
# Out:
# /home/ramondeb/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
model.fit(X=x.reshape(-1,1), y=y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
y_pred = model.predict(X=np.linspace(100, 150, 20).reshape(-1,1))

# %%
plt.plot(x, y, 'r')
plt.plot(np.linspace(100, 150, 20).reshape(-1,1), y_pred)

# %%
y_pred = model.predict(X=x.reshape(-1,1))

# %%
plot(x, y)
plot(x, y_pred, 'r')

# %%
model.score(x.reshape(-1,1), y)
# Out:
# 0.86673967764173343

# %%
def aproxima(x, y):
    x = x.reshape(-1,1)
    model.fit(X=x, y=y)
    return model.score(x, y)
def lineal_model(sigma, N=100):
    ruido = np.random.normal(size=N)
    x = np.linspace(0, 20, N)
    y = (5*x) + 1 + (ruido*sigma)
    x = x.reshape(-1,1)
    # plt.plot(x, y, 'ro')
    return x, y
fig, axes = plt.subplots(1,2)
axes = axes.reshape(-1,)
scores = []
for sigma in range(10, 1000):
    x, y = lineal_model(sigma)
    score = aproxima(x, y)
    scores.append(score)
axes[0].plot(scores)
fig.show()
plt.show()
# Out:
# /home/ramondeb/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:403: UserWarning: matplotlib is currently using a non-GUI backend, so cannot show the figure
#   "matplotlib is currently using a non-GUI backend, "

# %%
plt.boxplot([y, y_pred])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0xaaaac32c>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0xaaaa35ec>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0xaaa7128c>,
# ...
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0xaaa7162c>,
# ...
#  'whiskers': [<matplotlib.lines.Line2D at 0xaaaacacc>,
# ...
#   <matplotlib.lines.Line2D at 0xaaa7150c>]}
